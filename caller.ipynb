# %%
from importlib import reload
import CET_logic_middle  # 이미 로드되어 있는 모듈

reload(CET_logic_middle)  # 수정된 .py 파일 내용을 다시 반영
# 모듈이 재로딩된 상태에서 함수를 호출
from datetime import datetime

now_str = datetime.now().strftime("%Y%m%d_%H%M%S")
output_path_with_timestamp = f"C:/Users/user/Desktop/연구사업부/code/CET logic/example_test_{now_str}.xlsx"

CET_logic_middle.cet_process(
    input_path="C:/Users/user/Desktop/연구사업부/code/CET logic/example_중등.xlsx",
    score_path="C:/Users/user/Desktop/연구사업부/code/CET logic/score_middle.xlsx",
    output_path=output_path_with_timestamp
)

print("CET 로직 수행 완료!")
# Out:
#     Int_1  Int_2  Int_3  Int_4  Int_5  Int_6  Int_7  Int_8  Int_9  Int_10  \
# 0       1      3      2      1      1      4      1      4      4       1
# 1       3      3      3      3      1      2      2      1      3       3
# 2       1      3      3      3      1      1      1      1      3       1
# 3       1      3      2      3      3      4      1      1      4       4
# 4       3      3      1      3      2      4      3      2      4       1
# 5       1      3      1      3      3      3      2      1      1       3
# 6       1      3      1      3      2      2      1      1      4       3
# 7       1      3      4      3      2      1      4      3      1       3
# 8       1      3      4      4      3      4      3      3      4       1
# 9       1      3      2      3      3      4      2      2      4       4
# 10      3      2      1      4      1      2      1      3      1       1
# 11      1      2      2      4      3      1      2      1      2       3
# ...

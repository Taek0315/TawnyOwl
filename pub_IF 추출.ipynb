# %%
from argparse import ArgumentParser
from ast import literal_eval
from bs4 import BeautifulSoup
import requests
import urllib.request, urllib.parse, urllib.error
import numpy as np
import pandas as pd
import metapub
from metapub import PubMedFetcher, PubMedAuthor
import sys
from Bio import Entrez
from pathlib import Path
import os


import logging
import re

# %%
# 로깅 설정
log = logging.getLogger(__name__)
log.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
stream_handler = logging.StreamHandler()
stream_handler.setFormatter(formatter)
log.addHandler(stream_handler)

# Pubmed 데이터베이스 접속
def search_pubmed(org_name, year, month):
    """
    Searches PubMed for papers that meet the org and date criteria.
    """
    Entrez.email = "dylan@grkcon.com"  # API 아이디 입력, API 코드는 NCBI 개발자 환경에서 받을 수 있음
    try:
        handle = Entrez.esearch(db="pubmed",
                                term=f"{org_name}[affil] AND {year}/{month}/01:{year}/{str(int(month) + 1)}/01[dp]",
                                retmax=9999)
        record = Entrez.read(handle)
        log.debug("PubMed database connection successful.")
        return record['IdList']
    except Exception as e:
        log.error("Error connecting to PubMed database: %s", e)
        return []

# 검색 예시
search_pubmed("Chungbuk National University Hospital", "2024", "05")
# Out:
# 2024-05-14 11:59:47,207 - DEBUG - PubMed database connection successful.
# 2024-05-14 11:59:47,207 - DEBUG - PubMed database connection successful.
# ['38738926', '38730344', '38728497', '38720697', '38713078', '38700863', '38568686', '38556482', '38547767', '38411317', '38336490', '38331252']

# %%
org_name = "Chungbuk National University Hospital"
data_file =  r"C:\Users\오현택\Desktop\python\0514"
year = 2022
month = 1

# 로깅 설정
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# 로그를 출력할 로거(logger) 생성
log = logging.getLogger(__name__)


#Pubmed 데이터 베이스 접속
def search_pubmed(org_name, year, month):
    """
    Searches PubMed for papers that meet the org and date criteria.
    """
    Entrez.email = "dylan@grkcon.com" #API 아이디 입력, API 코드는 NCBI 개발자 환경에서 받을 수 있음
    try:
        handle = Entrez.esearch(db="pubmed", 
                            term=f"{org_name}[Chungbuk National University Hospital] AND {year}/{month}/01:{year}/{str(int(month) + 1)}/01[dp]", 
                            retmax=9999)
        record = Entrez.read(handle)
        log.debug("PubMed 접속 완료")
        return record['IdList']
    except Exception as e:
        log.error("Error connecting to PubMed database: %s", e)
        return []
search_pubmed("Chungbuk National University Hospital", "2022", "01")
# Out:
# 2024-05-14 11:59:57,236 - DEBUG - PubMed 접속 완료
# 2024-05-14 11:59:57,236 - DEBUG - PubMed 접속 완료
# ['36726749', '36704547', '36620625', '36405028', '36398236', '36341128', '36339930', '36317398', '36267638', '36262197', '36213459', '36211416', '36177347', '36124238', '36124066', '36121802', '36105055', '36017038', '35992880', '35992188', '35989920', '35847886', '35837570', '35783824', '35720840', '35719633', '35702115', '35702109', '35666742', '35573830', '35558886', '35510249', '35479279', '35444990', '35421154', '35359630', '35350572', '35281880', '35274010', '35252005', '35247953', '35237619', '35237059', '35232673', '35221600', '35221590', '35209705', '35203512', '35160167', '35158207', '35135065', '35128850', '35116221', '35103535', '35093635', '35089523', '35089229', '35070944', '35070940', '35069503', '35050964', '35043006', '35039576', '35034023', '35031884', '35021289', '35016269', '35015188', '35007247', '34997880', '34996990', '34993890', '34980137', '34980097', '34973183', '34973069', '34964278', '34862341', '34826609', '34800078', '34773897', '34768012', '34711784', '34670008', '34648948', '34645256', '34587325', '34510267', '34505976', '34481658', '34327707', '34320607', '34310541', '34304232', '34290076', '34080718', '32789837']

# %%
#정보 확인 및 데이터 검색 확인

def fetch_pubmed_details(ids):
    """
    Returns pubmed details from ids.
    """
    try:
        handle = Entrez.efetch(db="pubmed", id=ids, rettype="medline", retmode="text")
        records = handle.read()
        return records
    except Exception as e:
        print(f"Error fetching PubMed details: {e}")
        return ''

fetch_pubmed_details('36726749')
# Out:
# "\nPMID- 36726749\nOWN - NLM\nSTAT- PubMed-not-MEDLINE\nLR  - 20230203\nIS  - 1664-2295 (Print)\nIS  - 1664-2295 (Electronic)\nIS  - 1664-2295 (Linking)\nVI  - 13\nDP  - 2022\nTI  - The mortality of patients with Parkinson's disease with deep brain stimulation.\nPG  - 1099862\nLID - 10.3389/fneur.2022.1099862 [doi]\nLID - 1099862\nAB  - BACKGROUND: Deep brain stimulation (DBS) of the subthalamic nucleus (STN) is \n      effective in improving motor function in patients with Parkinson's disease (PD). \n      This study aimed to investigate mortality associated with bilateral STN DBS in \n      patients with PD and to assess the factors associated with mortality and causes \n      of death after DBS. METHODS: We reviewed the medical records of 257 patients with \n      PD who underwent bilateral STN DBS at the Movement Disorder Center at Seoul \n      National University Hospital between March 2005 and November 2018. Patients were \n      evaluated preoperatively, at 3, 6, and 12 months after surgery and annually \n      thereafter. The cause and date of death were obtained from interviews with \n      caregivers or from medical certificates at the last follow-up. RESULTS: Of the \n      257 patients with PD, 48 patients (18.7%) died, with a median time of death of \n      11.2 years after surgery. Pneumonia was the most common cause of death. Older age \n      of disease onset, preoperative falling score while on medication, and higher \n      preoperative total levodopa equivalent daily dose were associated with a higher \n      risk of mortality in time-dependent Cox regression analysis. CONCLUSION: These \n      results confirm the mortality outcome of STN DBS in patients with advanced PD.\nCI  - Copyright (c) 2023 Kim, Kim, Kim, Kim, Kim, Ong, Park, Paek and Jeon.\nFAU - Kim, Ahro\nAU  - Kim A\nAD  - Department of Neurology, Ulsan University Hospital, University of Ulsan College \n      of Medicine, Ulsan, Republic of Korea.\nFAU - Kim, Han-Joon\nAU  - Kim HJ\nAD  - Department of Neurology, College of Medicine, Seoul National University Hospital, \n      Seoul, Republic of Korea.\nFAU - Kim, Aryun\nAU  - Kim A\nAD  - Department of Neurology, Chungbuk National University Hospital, Cheongju, \n      Republic of Korea.\nFAU - Kim, Yoon\nAU  - Kim Y\nAD  - Department of Neurology, Young Tong Hyo Hospital, Suwon, Republic of Korea.\nFAU - Kim, Ahwon\nAU  - Kim A\nAD  - Department of Neurology, College of Medicine, Seoul National University Hospital, \n      Seoul, Republic of Korea.\nFAU - Ong, Jed Noel A\nAU  - Ong JNA\nAD  - Department of Neurosciences, Makati Medical Center, Makati, Philippines.\nFAU - Park, Hye Ran\nAU  - Park HR\nAD  - Department of Neurosurgery, Soonchunhyang University Seoul Hospital, Seoul, \n      Republic of Korea.\nFAU - Paek, Sun Ha\nAU  - Paek SH\nAD  - Department of Neurosurgery, College of Medicine, Seoul National University \n      Hospital, Seoul, Republic of Korea.\nFAU - Jeon, Beomseok\nAU  - Jeon B\nAD  - Department of Neurology, College of Medicine, Seoul National University Hospital, \n      Seoul, Republic of Korea.\nLA  - eng\nPT  - Journal Article\nDEP - 20230116\nPL  - Switzerland\nTA  - Front Neurol\nJT  - Frontiers in neurology\nJID - 101546899\nPMC - PMC9885091\nOTO - NOTNLM\nOT  - Parkinson's disease\nOT  - STN (subthalamic nucleus)\nOT  - deep brain stimulation\nOT  - mortality\nOT  - outcome\nCOIS- The authors declare that the research was conducted in the absence of any \n      commercial or financial relationships that could be construed as a potential \n      conflict of interest.\nEDAT- 2023/02/03 06:00\nMHDA- 2023/02/03 06:01\nPMCR- 2023/01/16\nCRDT- 2023/02/02 02:01\nPHST- 2022/11/16 00:00 [received]\nPHST- 2022/12/19 00:00 [accepted]\nPHST- 2023/02/02 02:01 [entrez]\nPHST- 2023/02/03 06:00 [pubmed]\nPHST- 2023/02/03 06:01 [medline]\nPHST- 2023/01/16 00:00 [pmc-release]\nAID - 10.3389/fneur.2022.1099862 [doi]\nPST - epublish\nSO  - Front Neurol. 2023 Jan 16;13:1099862. doi:  ...

# %%
#데이터 저장

def pubmed_extraction(org_name, data_file, year, month):
    """
    Extracts data from PubMed and saves it to a CSV file.
    """

    idlist = search_pubmed(org_name, year, month)

    fetch = PubMedFetcher()

    citation_list = []

    n = 0
    for id in idlist:
        article = fetch.article_by_pmid(id)
        mesh_terms = article.mesh.values()
        records = fetch_pubmed_details(id)
        affiliation = re.findall(r'AD  - (.+)', records)

        # Extract the affiliation
        full_affil = [''.join(aff) for aff in affiliation]
        corres_affil = [a for a in full_affil if "@" in a]

        # Extract mesh terms if available
        mesh = [v['descriptor_name'] for v in mesh_terms] if mesh_terms else []

        abstract = [article.abstract if article.abstract else ""]

        n += 1
        print(f"-----------{year}/{month} Completed: {n}/{len(idlist)}!-----------")

        try:
            auth_affil = ''.join(affiliation[0])
            # Check if the organization name is in the affiliation
            if org_name in auth_affil:
                department = auth_affil.split(',')[0]
                hospital = [a for a in auth_affil.split(',') if org_name in a]
                citation = [department, *hospital, article.title, article.journal, article.year, article.authors[0], len(article.authors), ", ".join(mesh), article.doi, article.issn, ", ".join(abstract)]
                citation_list.append(citation)
            elif org_name in corres_affil[0]:
                department = corres_affil[0].split(',')[0]
                hospital = [a for a in corres_affil[0].split(',') if org_name in a]
                citation = [department, *hospital, article.title, article.journal, article.year, article.authors[0], len(article.authors), ", ".join(mesh), article.doi, article.issn, ", ".join(abstract)]
                citation_list.append(citation)
        except IndexError:
            continue

    citation_df = pd.DataFrame(citation_list)[1:10]
    citation_df.columns = ["Department", "Hospital", "Title", "Journal", "Year", "Author", "Number of Authors", "MeSH", "DOI", "ISSN", "Abstract"]
    citation_df.to_csv(f"{data_file}/{org_name}_{year}_{month}-{str(int(month) + 1)}.csv", index=False, encoding="utf-8-sig")

pubmed_extraction("Chungbuk National University Hospital", r"C:\Users\오현택\Desktop\python\0514", "2022", "01")
# Out:
# 2024-05-14 12:04:42,950 - DEBUG - PubMed 접속 완료
# 2024-05-14 12:04:42,950 - DEBUG - PubMed 접속 완료
# -----------2022/01 Completed: 1/97!-----------
# -----------2022/01 Completed: 2/97!-----------
# -----------2022/01 Completed: 3/97!-----------
# -----------2022/01 Completed: 4/97!-----------
# -----------2022/01 Completed: 5/97!-----------
# -----------2022/01 Completed: 6/97!-----------
# -----------2022/01 Completed: 7/97!-----------
# -----------2022/01 Completed: 8/97!-----------
# -----------2022/01 Completed: 9/97!-----------
# -----------2022/01 Completed: 10/97!-----------
# -----------2022/01 Completed: 11/97!-----------
# -----------2022/01 Completed: 12/97!-----------
# -----------2022/01 Completed: 13/97!-----------
# -----------2022/01 Completed: 14/97!-----------
# -----------2022/01 Completed: 15/97!-----------
# -----------2022/01 Completed: 16/97!-----------
# -----------2022/01 Completed: 17/97!-----------
# -----------2022/01 Completed: 18/97!-----------
# -----------2022/01 Completed: 19/97!-----------
# -----------2022/01 Completed: 20/97!-----------
# -----------2022/01 Completed: 21/97!-----------
# -----------2022/01 Completed: 22/97!-----------
# -----------2022/01 Completed: 23/97!-----------
# -----------2022/01 Completed: 24/97!-----------
# -----------2022/01 Completed: 25/97!-----------
# -----------2022/01 Completed: 26/97!-----------
# -----------2022/01 Completed: 27/97!-----------
# -----------2022/01 Completed: 28/97!-----------
# -----------2022/01 Completed: 29/97!-----------
# -----------2022/01 Completed: 30/97!-----------
# -----------2022/01 Completed: 31/97!-----------
# -----------2022/01 Completed: 32/97!-----------
# -----------2022/01 Completed: 33/97!-----------
# -----------2022/01 Completed: 34/97!-----------
# -----------2022/01 Completed: 35/97!-----------
# -----------2022/01 Completed: 36/97!-----------
# -----------2022/01 Completed: 37/97!-----------
# -----------2022/01 Completed: 38/97!-----------
# -----------2022/01 Completed: 39/97!-----------
# -----------2022/01 Completed: 40/97!-----------
# -----------2022/01 Completed: 41/97!-----------
# -----------2022/01 Completed: 42/97!-----------
# -----------2022/01 Completed: 43/97!-----------
# -----------2022/01 Completed: 44/97!-----------
# -----------2022/01 Completed: 45/97!-----------
# -----------2022/01 Completed: 46/97!-----------
# -----------2022/01 Completed: 47/97!-----------
# -----------2022/01 Completed: 48/97!-----------
# -----------2022/01 Completed: 49/97!-----------
# -----------2022/01 Completed: 50/97!-----------
# -----------2022/01 Completed: 51/97!-----------
# -----------2022/01 Completed: 52/97!-----------
# -----------2022/01 Completed: 53/97!-----------
# -----------2022/01 Completed: 54/97!-----------
# -----------2022/01 Completed: 55/97!-----------
# -----------2022/01 Completed: 56/97!-----------
# -----------2022/01 Completed: 57/97!-----------
# -----------2022/01 Completed: 58/97!-----------
# -----------2022/01 Completed: 59/97!-----------
# -----------2022/01 Completed: 60/97!-----------
# -----------2022/01 Completed: 61/97!-----------
# -----------2022/01 Completed: 62/97!-----------
# -----------2022/01 Completed: 63/97!-----------
# -----------2022/01 Completed: 64/97!-----------
# -----------2022/01 Completed: 65/97!-----------
# -----------2022/01 Completed: 66/97!-----------
# -----------2022/01 Completed: 67/97!-----------
# -----------2022/01 Completed: 68/97!-----------
# -----------2022/01 Completed: 69/97!-----------
# -----------2022/01 Completed: 70/97!-----------
# -----------2022/01 Completed: 71/97!-----------
# -----------2022/01 Completed: 72/97!-----------
# -----------2022/01 Completed: 73/97!-----------
# -----------2022/01 Completed: 74/97!-----------
# -----------2022/01 Completed: 75/97!-----------
# -----------2022/01 Completed: 76/97!-----------
# -----------2022/01 Completed: 77/97!-----------
# -----------2022/01 Completed: 78/97!-----------
# -----------2022/01 Completed: 79/97!-----------
# -----------2022/01 Completed: 80/97!-----------
# -----------2022/01 Completed: 81/97!-----------
# -----------2022/01 Completed: 82/97!-----------
# -----------2022/01 Completed: 83/97!-----------
# -----------2022/01 Completed: 84/97!-----------
# -----------2022/01 Completed: 85/97!-----------
# -----------2022/01 Completed: 86/97!-----------
# -----------2022/01 Completed: 87/97!-----------
# -----------2022/01 Completed: 88/97!-----------
# -----------2022/01 Completed: 89/97!-----------
# -----------2022/01 Completed: 90/97!-----------
# -----------2022/01 Completed: 91/97!-----------
# -----------2022/01 Completed: 92/97!-----------
# -----------2022/01 Completed: 93/97!-----------
# -----------2022/01 Completed: 94/97!-----------
# -----------2022/01 Completed: 95/97!-----------
# -----------2022/01 Completed: 96/97!-----------
# -----------2022/01 Completed: 97/97!-----------

# %%
import pandas as pd
from argparse import ArgumentParser
from ast import literal_eval
import glob
import os
import re
from rapidfuzz import process, fuzz
import logging
from pathlib import Path

log = logging.getLogger(__name__)

# %%
def get_files(data_path):
    files = glob.glob('{}/*.{}'.format(data_path, 'csv'))
    df = pd.concat([pd.read_csv(file, usecols=["Department", "Hospital", "Title", "Journal", "Year", "Author", "Number of Authors", "MeSH", "DOI", "ISSN", "Abstract"]) for file in files])
    return df

department_mapping = {
    'Gastroenterology': '소화기내과',
    'Cardiology': '순환기내과',
    'Pulmonology': '호흡기내과',
    'Nephrology': '신장내과',
    'Rheumatology': '류마티스내과',
    'Endocrinology': '내분비내과',
    'Infectious': '감염내과',
    'Hematology': '혈액종양내과',
    'Oncology': '혈액종양내과',
    'Internal': '내과',
    'Upper Gastrointestinal': '위장관외과(상부)',
    'Hepatobiliary': '간담췌외과',
    'Colorectal': '대장항문외과',
    'Endocrine': '유방내분비외과',
    'Vascular': '이식혈관외과',
    'Trauma': '중환자외상외과',
    'Surgery': '외과',
    'Pediatric': '소아외과',
    'Cardiothoracic': '심장혈관흉부외과',
    'Orthopedic': '정형외과',
    'Neurosurgery': '신경외과',
    'Plastic': '성형외과',
    'Obstetrics and Gynecology': '산부인과',
    'Pediatrics': '소아과',
    'Psychiatry': '정신건강의학과',
    'Neurology': '신경과',
    'Oral': '치과',
    'Ophthalmology': '안과',
    'Otorhinolaryngology': '이비인후과',
    'Dermatology': '피부과',
    'Urology': '비뇨의학과',
    'Rehabilitation': '재활의학과',
    'Physical': '재활의학과',
    'Family Medicine': '가정의학과',
    'Dentistry': '치과',
    'Laboratory Medicine': '진단검사의학과',
    'Radiation Oncology': '방사선종양학과',
    'Radiation': '방사선종양학과',
    'Anesthesiology': '마취통증의학과',
    'Pathology': '병리과',
    'Radiology': '영상의학과',
    'Emergency Medicine': '응급의학과',
    'Nuclear Medicine': '핵의학과',
    'Clinical Pharmacology': '임상약리학과',
    'Health Screening': '건진센터',
    'Thyroid': '갑상선센터',
    'International': '국제진료센터',
    'Care': '생활치료센터',
    'Screening': '선별진료소과(소)',
    'Transplant': '이식외과',
    'COVID-19': '코로나19',
    'Division of Cardiology' : '심장내과',
    'Internal Medicine' : '내과'
}

# %%
df = get_files(r"C:\Users\오현택\Desktop\python\0514")

# %%
# "Department" 열의 값을 변경하여 "Department of"를 삭제
df['Department'] = df['Department'].str.replace('Department of ', '')

# %%
#진료과 한국어로 변경

for i, department in enumerate(df['Department']):
    kor_department = department_mapping.get(department, None)
    if kor_department:
        df.loc[i, 'Department_KOR'] = kor_department
    else:
        print(f"Error: Unrecognized department name '{department}'")

# Department_KOR 열이 없는 경우 빈 값으로 채우기
df['Department_KOR'] = df['Department_KOR'].fillna('')

# %%
cwts = pd.read_csv("C:/Users/오현택/Desktop/python/cwts.csv")
cwts_year = pd.pivot_table(cwts, values = 'SNIP', index = ['Source title', 'Electronic ISSN'], columns = "Year").reset_index()

# %%
years = [str(i) for i in range(1999, 2023)]

cwts_year.columns = list(["Full Journal", "ISSN", *years])
cwts_year = cwts_year[["Full Journal", "ISSN", "2022"]]
dictionary = cwts_year[["2022", "ISSN"]].set_index("ISSN").to_dict()['2022']

# %%
def output_IF(org_name, out_path):
    dictionary = create_dictionary()

    ######20240202 cyw ISSN 번호에 따라 IF 번호 저장
    df = pd.read_csv(f"{out_path}/{org_name}_KOR.csv", encoding="utf-8-sig")
    df['IF'] = df['ISSN'].apply(lambda x: dictionary.get(x, None))

    df[['Department', 'KOR', 'Year', 'Journal', 'DOI', 'IF']].drop_duplicates().to_csv(f"{out_path}/{org_name}_IF_stats.csv", encoding='utf-8-sig', index = False)

# %%
df['IF'] = df['ISSN'].map(dictionary)

    # 중복 행을 제거하고 DataFrame을 CSV 파일로 저장합니다.
df[['Department', 'Year', 'Journal', 'DOI', 'IF']].drop_duplicates()
df['IF'] = df['IF'].fillna(np.nan)

df
# Out:
#                   Department                                Hospital  \
# 0                 Cardiology   Chungbuk National University Hospital
# 1        Otorhinolaryngology   Chungbuk National University Hospital
# 2                    Surgery   Chungbuk National University Hospital
# 3     Division of Cardiology   Chungbuk National University Hospital
# 4         Radiation Oncology   Chungbuk National University Hospital
# 5  Obstetrics and Gynecology   Chungbuk National University Hospital
# 6                Dermatology   Chungbuk National University Hospital
# 7                 Pediatrics   Chungbuk National University Hospital
# 8          Internal Medicine   Chungbuk National University Hospital
#
#                                                Title               Journal  \
# 0  Deep Learning Model for Predicting Rhythm Outc...         J Healthc Eng
# 1  Effects of CoQ10 Replacement Therapy on the Au...        Biomed Res Int
# 2  The Risk Factors, Incidence and Prognosis of P...           Front Oncol
# 3  Case Report: Delayed Ventricular Pseudoaneurys...  Front Cardiovasc Med
# 4  Fused toes homolog, a potential molecular regu...              PLoS One
# 5  Awareness, intentions and attitudes towards pl...  Reprod Biomed Online
# 6  A Case of Primary Cutaneous Extraskeletal Ewin...          Ann Dermatol
# 7  Association of Tandem Repeat Number Variabilit...            J Clin Med
# 8  A case report of nilotinib-induced irreversibl...  Medicine (Baltimore)
#
#    Year  Author  Number of Authors  \
# 0  2022  Lee DI                  4
# 1  2022  Nam DW                 15
# 2  2022  Park S                 13
# 3  2022   Kim M                  8
# 4  2022   D S P                  6
# 5  2022  Kim SM                  7
# 6  2022  Lee JW                  4
# 7  2022  Lee JK                  4
# 8  2022  Cho JY                  5
#
#                                                 MeSH  \
# 0  Atrial Fibrillation, Catheter Ablation, Deep L...
# 1  Ataxia, Deafness, Hearing Loss, Sensorineural,...
# 2                                                NaN
# 3                                                NaN
# 4  Cell Line, Tumor, Female, Human papillomavirus...
# 5  Attitude, Cross-Sectional Studies, Cryopreserv...
# 6                                                NaN
# 7                                                NaN
# 8  Adrenal Cortex Hormones, Biopsy, Cough, Humans...
#
#                             DOI       ISSN  \
# 0          10.1155/2022/2863495  2040-2309
# 1          10.1155/2022/5250254  2314-6141
# 2      10.3389/fonc.2022.889433  2234-943X
# 3      10.3389/fcvm.2022.887190  2297-055X
# 4  10.1371/journal.pone.0266532  1932-6203
# 5    10.1016/j.rbmo.2022.01.002  1472-6491
# 6       10.5021/ad.2022.34.1.72  2005-3894
# 7           10.3390/jcm11030715  2077-0383
# 8   10.1097/MD.0000000000028701  1536-5964
#
#                                             Abstract Department_KOR    IF
# 0  Current guidelines on atrial fibrillation (AF)...          순환기내과  0.91
# 1  Primary coenzyme Q10 (CoQ10) deficiency refers...          이비인후과  0.97
# 2  The term 'pregnancy-associated breast cancer' ...             외과   NaN
# 3  A 74-year-old woman presented with incessant w...           심장내과  1.44
# 4  Human papillomavirus type 16 (HPV16) plays a m...        방사선종양학과   NaN
# 5  RESEARCH QUESTION: What are the awareness, int...           산부인과  1.27
# 6  Primary cutaneous extraskeletal Ewing sarcoma ...            피부과  0.60
# 7                                                NaN            소아과  1.18
# 8  RATIONALE: Nilotinib is a second line tyrosine...             내과  0.80

# %%
df.columns
# Out:
# Index(['Department', 'Hospital', 'Title', 'Journal', 'Year', 'Author',
#        'Number of Authors', 'MeSH', 'DOI', 'ISSN', 'Abstract',
#        'Department_KOR', 'IF'],
#       dtype='object')

# %%
# 컬럼순서 정리
desired_columns = ['Department', 'Department_KOR', 'Hospital', 'Title', 'Journal', 'Year', 'Author','ISSN', 'IF','Number of Authors', 'MeSH', 'DOI', 'Abstract']


df = df.reindex(columns=desired_columns)

# %%
df
# Out:
#                   Department Department_KOR  \
# 0                 Cardiology          순환기내과
# 1        Otorhinolaryngology          이비인후과
# 2                    Surgery             외과
# 3     Division of Cardiology           심장내과
# 4         Radiation Oncology        방사선종양학과
# 5  Obstetrics and Gynecology           산부인과
# 6                Dermatology            피부과
# 7                 Pediatrics            소아과
# 8          Internal Medicine             내과
#
#                                  Hospital  \
# 0   Chungbuk National University Hospital
# 1   Chungbuk National University Hospital
# 2   Chungbuk National University Hospital
# 3   Chungbuk National University Hospital
# 4   Chungbuk National University Hospital
# 5   Chungbuk National University Hospital
# 6   Chungbuk National University Hospital
# 7   Chungbuk National University Hospital
# 8   Chungbuk National University Hospital
#
#                                                Title               Journal  \
# 0  Deep Learning Model for Predicting Rhythm Outc...         J Healthc Eng
# 1  Effects of CoQ10 Replacement Therapy on the Au...        Biomed Res Int
# 2  The Risk Factors, Incidence and Prognosis of P...           Front Oncol
# 3  Case Report: Delayed Ventricular Pseudoaneurys...  Front Cardiovasc Med
# 4  Fused toes homolog, a potential molecular regu...              PLoS One
# 5  Awareness, intentions and attitudes towards pl...  Reprod Biomed Online
# 6  A Case of Primary Cutaneous Extraskeletal Ewin...          Ann Dermatol
# 7  Association of Tandem Repeat Number Variabilit...            J Clin Med
# 8  A case report of nilotinib-induced irreversibl...  Medicine (Baltimore)
#
#    Year  Author       ISSN    IF  Number of Authors  \
# 0  2022  Lee DI  2040-2309  0.91                  4
# 1  2022  Nam DW  2314-6141  0.97                 15
# 2  2022  Park S  2234-943X   NaN                 13
# 3  2022   Kim M  2297-055X  1.44                  8
# 4  2022   D S P  1932-6203   NaN                  6
# 5  2022  Kim SM  1472-6491  1.27                  7
# 6  2022  Lee JW  2005-3894  0.60                  4
# 7  2022  Lee JK  2077-0383  1.18                  4
# 8  2022  Cho JY  1536-5964  0.80                  5
#
#                                                 MeSH  \
# 0  Atrial Fibrillation, Catheter Ablation, Deep L...
# 1  Ataxia, Deafness, Hearing Loss, Sensorineural,...
# 2                                                NaN
# 3                                                NaN
# 4  Cell Line, Tumor, Female, Human papillomavirus...
# 5  Attitude, Cross-Sectional Studies, Cryopreserv...
# 6                                                NaN
# 7                                                NaN
# 8  Adrenal Cortex Hormones, Biopsy, Cough, Humans...
#
#                             DOI  \
# 0          10.1155/2022/2863495
# 1          10.1155/2022/5250254
# 2      10.3389/fonc.2022.889433
# 3      10.3389/fcvm.2022.887190
# 4  10.1371/journal.pone.0266532
# 5    10.1016/j.rbmo.2022.01.002
# 6       10.5021/ad.2022.34.1.72
# 7           10.3390/jcm11030715
# 8   10.1097/MD.0000000000028701
#
#                                             Abstract
# 0  Current guidelines on atrial fibrillation (AF)...
# 1  Primary coenzyme Q10 (CoQ10) deficiency refers...
# 2  The term 'pregnancy-associated breast cancer' ...
# 3  A 74-year-old woman presented with incessant w...
# 4  Human papillomavirus type 16 (HPV16) plays a m...
# 5  RESEARCH QUESTION: What are the awareness, int...
# 6  Primary cutaneous extraskeletal Ewing sarcoma ...
# 7                                                NaN
# 8  RATIONALE: Nilotinib is a second line tyrosine...

# %%
df.to_excel("C:\\Users\\오현택\\Desktop\\python\\IF_output0514.xlsx")

# %%
dictionary
# Out:
# {'-': 1.23,
#  '2053-1583': 1.13,
#  '2190-5738': 0.81,
#  '2329-7670': 1.1,
#  '2092-6731': 1.6,
#  '2550-2247': 0.83,
#  '2013-3294': 0.45,
#  '1614-2411': 1.51,
#  '1662-8667': 0.24,
#  '1984-4182': 0.64,
#  '2575-3126': 0.65,
#  '2214-7233': nan,
#  '1477-3848': 2.07,
#  '2376-0605': 0.45,
#  '1844-9166': 0.46,
#  '1559-7776': 0.49,
#  '2162-5239': 0.38,
#  '2375-5717': 0.14,
#  '1825-1242': 0.32,
#  '2210-738X': nan,
#  '1530-9932': 0.88,
#  '2515-9321': 0.59,
#  '2330-5517': 0.3,
#  '2330-5525': 0.0,
#  '2145-4493': 0.43,
#  '2326-3253': 0.0,
#  '1932-2240': 0.17,
#  '1557-7341': 7.15,
#  '2153-2192': 1.19,
#  '1550-4840': 1.01,
#  '1551-3688': 1.78,
#  '1558-1160': nan,
#  '1936-7236': 1.23,
#  '1549-6333': 1.71,
#  '1544-3965': 0.84,
#  '1558-3430': nan,
#  '2375-4702': 1.11,
#  '1556-4703': 1.31,
#  '1942-3462': 0.71,
#  '1557-945X': 1.07,
#  '1557-7333': 1.2,
#  '1557-7325': 2.26,
#  '1946-6226': 2.07,
#  '2637-8051': 1.0,
#  '2378-9638': 1.2,
#  '1557-4644': 1.55,
#  '1557-7309': 0.83,
#  '2167-8383': 1.48,
#  '1557-7368': 3.05,
#  '2573-9522': 2.12,
#  '1558-2868': 3.49,
#  '1557-7406': nan,
#  '2157-6912': 3.31,
#  '2160-6463': 1.17,
#  '1557-6051': 1.3,
#  '1556-472X': 1.9,
#  '2158-6578': 0.94,
#  '1557-7295': 2.24,
#  '1558-1195': 1.14,
#  '2376-3647': 0.47,
#  '1551-6865': 1.68,
#  '2329-4957': 1.21,
#  '2471-2574': 1.44,
#  '1558-4593': 0.94,
#  '1936-7414': 1.42,
#  '1550-4867': 1.16,
#  '1557-7392': 2.2,
#  '2374-0361': 0.62,
#  '1550-4883': nan,
#  '1553-3093': 1.6,
#  '1559-114X': 1.67,
#  '2578-5745': 0.97,
#  '2305-7394': 0.37,
#  '2692-1952': 0.55,
#  '2576-6422': 0.72,
#  '2637-6113': 1.06,
#  '2574-0962': 0.96,
#  '2574-0970': 1.01,
#  '2637-6105': 0.97,
#  '2694-2437': 0.48,
#  '2373-9878': 0.89,
#  '2155-5435': 2.13,
#  '2374-7951': 2.36,
#  '1554-8937': 0.96,
#  '1948-7193': 0.95,
#  '2156-8944': 0.99,
#  '2690-0637': 0.79,
#  '2472-3452': 0.85,
#  '2380-8195': 2.68,
#  '2694-2518': 0.61,
#  '2692-1944': 0.57,
#  '2373-8227': 0.99,
#  '2161-1653': 1.24,
#  '2694-2461': 0.96,
#  '2639-4979': 1.49,
#  '1948-5875': 0.87,
#  '1936-086X': 2.42,
#  '2694-2496': 1.07,
#  '2470-1343': 0.94,
#  '2575-9108': 1.1,
#  '2330-4022': 1.67,
#  '2379-3694': 1.54,
#  '2168-0485': 1.37,
#  '1947-5918': 0.28,
#  '2161-5063': 0.96,
#  '1944-8252': 1.43,
#  '1536-593X': 0.59,
#  '1982-0194': 0.78,
#  '2313-6545': nan,
#  '1866-6647': 1.55,
#  '1848-7718': 0.74,
#  '2472-5390': 0.89,
#  '2332-8584': 1.52,
#  '1618-0399': 1.29,
#  '2509-713X': 0.21,
#  '2371-9621': 1.83,
#  '2666-6510': 15.74,
#  '1435-5655': 1.6,
#  '1533-385X': 1.45,
#  '2155-7209': 0.62,
#  '2239-6152': 0.42,
#  '1578-9705': 0.77,
#  '2204-4183': 0.15,
#  '1547-5905': 1.2,
#  '1473-5571': 1.25,
#  '1360-0451': 0.84,
#  '1943-2755': 0.76,
#  '1557-7449': 1.56,
#  '1931-8405': 0.51,
#  '2090-1259': 1.33,
#  '1698-6997': 0.57,
#  '1573-3254': 1.39,
#  '1542-8125': nan,
#  '1881-8188': 0.87,
#  '1570-5595': 0.57,
#  '2471-2086': 0.95,
#  '2377-9098': 0.67,
#  '2578-1588': 0.49,
#  '2333-8334': 0.75,
#  '2372-0352': 0.42,
#  '2372-0468': 0.9,
#  '2473-6988': 0.96,
#  '2471-1888': 1.35,
#  '2373-7972': 0.67,
#  '2327-8994': 0.88,
#  '1551-7616': 0.25,
#  '2473-3458': 0.02,
#  '2520-4890': 0.19,
#  '2398-7723': 0.48,
#  '2329-4523': 1.3,
#  '2150-7759': 0.99,
#  '2666-5778': 0.35,
#  '2157-7005': 0.45,
#  '1475-4541': 0.94,
#  '1741-1629': nan,
#  '2191-0855': 1.02,
#  '2520-0518': 0.54,
#  '1334-6253': 0.34,
#  '1869-8182': 2.3,
#  '2663-0419': 0.94,
#  '1940-3364': 0.1,
#  '1445-2197': 0.65,
#  '1446-8735': 0.47,
#  '1878-0369': 0.55,
#  '2171-6315': 0.14,
#  '2473-2877': 1.13,
#  '2166-532X': 1.45,
#  '2378-0967': 1.74,
#  '1600-0463': 0.79,
#  '1600-5503': nan,
#  '2321-1407': 0.19,
#  '2048-7703': 1.59,
#  '0717-6996': 0.4,
#  '2162-2582': 0.0,
#  '2251-6638': 0.38,
#  '2173-6847': 0.85,
#  '1538-943X': 1.35,
#  '2376-7642': 0.94,
#  '2332-9025': 0.89,
#  '2586-9159': 0.26,
#  '1505-5337': nan,
#  '2655-5409': 0.31,
#  '2224-9028': 0.58,
#  '0364-9962': 0.29,
#  '1783-1350': 1.66,
#  '2108-6354': 0.01,
#  '1863-818X': 1.32,
#  '1863-8163': nan,
#  '2632-3559': 1.12,
#  '0718-7262': 0.31,
#  '2639-0213': 2.73,
#  '2577-8161': 0.79,
#  '2164-9731': 0.27,
#  '1467-6281': 1.39,
#  '2366-0058': 1.0,
#  '1865-8784': 0.64,
#  '1837-9389': 0.07,
#  '2014-8534': 0.65,
#  '1687-0409': 0.53,
#  '2241-1402': 0.15,
#  '1810-4851': 0.17,
#  '2056-5127': 0.55,
#  '1553-2712': 1.46,
#  '1925-3621': 0.59,
#  '2281-4612': 0.37,
#  '1938-808X': 2.19,
#  '2374-2895': 0.49,
#  '1876-2867': 1.28,
#  '1545-7230': 0.93,
#  '1904-0008': 0.07,
#  '1936-4709': nan,
#  '1878-4046': 1.45,
#  '2335-4194': 0.26,
#  '1528-2635': 0.36,
#  '1939-2249': nan,
#  '1528-2686': 0.27,
#  '1941-6067': 8.62,
#  '1528-2678': nan,
#  '1939-6104': 0.46,
#  '1712-7432': 0.24,
#  '2221-5115': 0.6,
#  '2107-7207': 0.86,
#  '2663-0583': 0.14,
#  '1879-2057': 2.0,
#  '1545-5815': 1.32,
#  '2369-7407': 0.64,
#  '1468-4489': 2.11,
#  '1467-6303': 1.25,
#  '2327-4468': 0.23,
#  '1749-3374': 1.2,
#  '2155-286X': 1.26,
#  '1558-7975': 1.41,
#  '1911-3838': 0.57,
#  '1558-7967': 3.48,
#  '2159-4260': 1.47,
#  '1467-629X': 1.39,
#  '1744-9499': 1.36,
#  '2152-2820': 0.53,
#  '1520-4898': 3.53,
#  '2643-6728': 2.06,
#  '1432-0517': 0.67,
#  '2444-3948': 0.34,
#  '1562-6865': 0.8,
#  '1347-5177': 0.43,
#  '1839-2571': 0.85,
#  '2280-6458': 0.38,
#  '2199-6067': 0.61,
#  '1588-2519': 0.87,
#  '2681-4617': 0.7,
#  '1846-0453': 0.49,
#  '1651-1972': 0.43,
#  '1651-1913': 0.77,
#  '1854-1941': 0.28,
#  '2300-357X': 0.67,
#  '2323-0118': 0.25,
#  '1588-2527': nan,
#  '1588-2535': 0.41,
#  '2736-5239': 0.0,
#  '1399-6576': 0.96,
#  '1874-6349': 0.84,
#  '1644-3276': 0.14,
#  '1588-2543': 0.0,
#  '1572-9036': 0.96,
#  '1600-0390': 0.79,
#  '1588-2551': 0.57,
#  '2451-0300': 0.01,
#  '1730-6264': 1.21,
#  '2449-8653': 0.0,
#  '2228-2017': 0.7,
#  '2392-2389': 0.55,
#  '1734-154X': 0.5,
#  '1745-7270': 0.58,
#  '1726-569X': 0.46,
#  '1900-1649': 0.35,
#  '1898-0295': 0.5,
#  '2412-1908': 0.93,
#  '1588-4082': 0.24,
#  '1878-7568': 1.73,
#  '2531-6745': 0.72,
#  '2587-9596': 0.12,
#  '1572-8358': 0.47,
#  '1503-111X': 0.64,
#  '1677-941X': 0.78,
#  '1847-8476': 0.54,
#  '1588-2578': 0.85,
#  '2448-7589': 0.65,
#  '2443-4264': 0.0,
#  '1784-973X': 0.54,
#  '1580-2612': 0.41,
#  '1580-3155': 0.46,
#  '1805-4404': 0.22,
#  '2577-0160': 0.67,
#  '1678-2674': 0.41,
#  '2227-538X': 0.09,
#  '2295-3337': 0.68,
#  '1333-9451': 0.5,
#  '1909-9711': 0.6,
#  '1684-1999': 0.2,
#  '2053-2733': 0.9,
#  '1600-5740': nan,
#  '2052-5206': 0.79,
#  '1600-5759': nan,
#  '2059-7983': 1.47,
#  '2056-9890': 0.38,
#  '1600-5368': nan,
#  '2053-230X': 0.3,
#  '1938-2650': 1.03,
#  '1651-2057': 1.05,
#  '1581-2979': 0.69,
#  '1847-6538': 0.3,
#  '1432-5233': 1.12,
#  '2535-8219': 0.45,
#  '1843-066X': 0.41,
#  '1242-1383': nan,
#  '1804-6487': 0.82,
#  '2524-4434': 0.44,
#  '1588-2586': 0.19,
#  '1437-9546': 0.56,
#  '2217-2521': 0.06,
#  '2571-0273': 0.0,
#  '1336-9245': 0.16,
#  '2365-7499': 0.78,
#  '2213-5820': 0.63,
#  '2451-0319': 0.37,
#  '1581-8314': 0.67,
#  '2300-1887': 0.61,
#  '1755-6724': 0.6,
#  '1338-5674': 0.31,
#  '1895-7455': 0.95,
#  '0898-9591': 0.86,
#  '1861-1133': 2.28,
#  '2336-4920': 0.62,
#  '1421-9662': 1.0,
#  '2300-7117': 0.22,
#  '1881-3593': 0.05,
#  '1827-9643': 0.33,
#  '1618-0372': 0.62,
#  '1347-5800': 0.71,
#  '1588-2608': nan,
#  '1736-7476': 0.93,
#  '2351-6526': 0.0,
#  '2406-6168': 0.17,
#  '2644-4690': 0.16,
#  '1581-0267': 0.34,
#  '2221-870X': 0.61,
#  '1734-1515': 0.64,
#  '1432-0525': 0.84,
#  '1986-5988': 1.13,
#  '1805-4951': 0.47,
#  '2300-5599': 0.62,
#  '1588-2616': nan,
#  '2092-1357': 0.1,
#  '2179-975X': 0.53,
#  '2232-3317': 0.66,
#  '1949-0763': 1.23,
#  '2669-218X': 0.26,
#  '2658-4069': 0.35,
#  '0717-6848': 0.13,
#  '1339-5629': 0.46,
#  '2668-7763': 0.25,
#  '1871-2509': 4.12,
#  '1786-0091': nan,
#  '1588-2632': 1.05,
#  '1572-9087': 0.76,
#  '1439-7617': 0.78,
#  '1336-0310': 0.54,
#  '2315-4144': 0.72,
#  '1618-3932': 0.61,
#  '1619-6937': 1.04,
#  '1614-3116': 1.14,
#  '1860-2134': 0.8,
#  '2300-5319': 0.59,
#  '1563-2571': nan,
#  '1735-9694': 0.18,
#  '2029-4174': 0.16,
#  '2283-9720': 0.06,
#  '2094-9278': 0.16,
#  '1646-0758': 0.57,
#  '1840-3956': 0.0,
#  '2194-1289': 1.15,
#  '1338-1156': 0.33,
#  '2603-3755': 0.25,
#  '1588-2640': 0.48,
#  '1339-3103': 0.69,
#  '2571-4686': 0.05,
#  '2353-074X': 0.23,
#  '2532-1900': 1.25,
#  '2350-417X': 0.58,
#  '1689-0035': 0.35,
#  '0942-0940': 1.3,
#  '2197-8395': nan,
#  '2240-2993': 0.93,
#  '1600-0404': 1.1,
#  '1600-5449': nan,
#  '1432-0533': 2.77,
#  '1601-5215': 0.74,
#  '1474-0508': 9.86,
#  '1600-0412': 1.72,
#  '1869-1099': 0.65,
#  '1502-3850': 0.97,
#  '1588-2659': 0.54,
#  '1651-226X': 1.13,
#  '1755-3768': 1.63,
#  '1588-2667': 0.79,
#  '1745-3682': 1.87,
#  '2589-1294': 0.99,
#  '1745-3704': nan,
#  '1651-2251': 0.88,
#  '1827-675X': 1.26,
#  '1988-3013': 0.55,
#  '1648-665X': 0.39,
#  '1651-2227': 1.05,
#  '2082-0259': 0.57,
#  '1732-2421': 0.91,
#  '2248-3802': 0.38,
#  '1896-1851': 0.8,
#  '2014-2986': 0.03,
#  '2395-8235': 0.14,
#  '2406-095X': 0.56,
#  '2095-8927': 0.71,
#  '1846-9558': 1.02,
#  '2211-3843': 2.36,
#  '1745-7254': 1.51,
#  '1825-6562': 0.28,
#  '1827-1766': 0.44,
#  '1588-2675': nan,
#  '1786-3767': nan,
#  '1898-794X': 0.36,
#  '1509-5770': 0.29,
#  '1336-040X': 0.09,
#  '1861-1664': 0.86,
#  '1748-1716': 1.29,
#  '1588-2691': 0.38,
#  '2189-7042': 0.44,
#  '2448-735X': 0.02,
#  '1741-1416': 1.23,
#  '1803-8220': 0.48,
#  '2450-8462': 0.09,
#  '1805-2363': 0.42,
#  '1689-0027': 0.36,
#  '1600-0447': 2.02,
#  '1600-5473': nan,
#  '1873-6297': 0.84,
#  '1600-0455': 0.82,
#  '2178-7727': 0.55,
#  '1679-9216': 0.22,
#  '1807-8621': 0.75,
#  '1807-8672': 0.78,
#  '1807-863X': 0.32,
#  '2178-5201': 0.19,
#  '1807-8648': 0.15,
#  '1807-8664': 0.39,
#  '1983-4683': 0.24,
#  '2450-0771': 0.44,
#  '1898-9594': 0.5,
#  '1787-064X': 0.21,
#  '2083-9480': 0.61,
#  '1502-3869': 1.48,
#  '1846-0410': 0.87,
#  '1820-1202': 0.02,
#  '1338-5267': 0.77,
#  '2309-9089': 0.31,
#  '1873-6254': 1.03,
#  '1848-6061': 0.48,
#  '2336-6478': 0.0,
#  '2336-3231': 0.0,
#  '2336-3398': 0.01,
#  '2336-1980': 0.35,
#  '2344-150X': nan,
#  '2449-8831': 0.0,
#  '2066-7752': 0.88,
#  '2391-8179': 0.3,
#  '1820-7448': 0.31,
#  '1801-7576': 0.4,
#  '2619-905X': 0.41,
#  '1588-2705': 0.48,
#  '1751-0147': 1.18,
#  '1336-2305': 0.42,
#  '1827-1774': nan,
#  '1463-6395': 0.81,
#  '2603-3798': 0.4,
#  '2053-2296': 0.34,
#  '2228-4699': 0.62,
#  '2051-5960': 1.29,
#  '1578-2190': 0.54,
#  '1578-2735': 0.47,
#  '1699-7980': 0.4,
#  '1476-7341': 0.7,
#  '1741-2617': 1.35,
#  '2158-6098': 0.99,
#  '1741-2625': 3.35,
#  '1563-5031': 0.62,
#  '1338-4015': 0.11,
#  '1544-4368': 0.98,
#  '2386-4567': 0.08,
#  '2105-2409': 0.0,
#  '1669-8983': 0.03,
#  '2076-0825': 0.98,
#  '2167-9010': 0.5,
#  '1759-9873': 1.12,
#  '1748-295X': nan,
#  '2040-3860': nan,
#  '1747-4892': 0.27,
#  '2586-6060': 1.07,
#  '2659-5885': 0.29,
#  '1552-0633': 0.25,
#  '1755-0645': 1.24,
#  '1867-4542': nan,
#  '1543-2777': 1.01,
#  '1741-2633': 0.76,
#  '2198-7335': 0.62,
#  '1360-0443': 2.02,
#  '1369-1600': 0.94,
#  '1476-7392': 1.25,
#  '1940-0640': 0.96,
#  '1873-6327': 1.37,
#  '2352-8532': 1.2,
#  '2214-8604': 2.48,
#  '1873-5312': nan,
#  '2192-8681': 0.0,
#  '2195-6545': nan,
#  '2162-397X': 0.82,
#  '2559-6489': 0.78,
#  '2449-9471': 0.44,
#  '1573-3289': 1.21,
#  '1552-3039': 1.57,
#  '1544-4376': nan,
#  '1930-3815': 5.54,
#  '2076-3387': 1.02,
#  '1949-0461': 1.82,
#  '2177-5281': 0.12,
#  '2363-8354': 2.47,
#  '1740-469X': 0.68,
#  '1544-452X': 0.76,
#  '1572-8757': 0.83,
#  '2048-4038': 0.77,
#  '1552-3047': 1.23,
#  '2162-4070': 1.13,
#  '1744-1803': 0.3,
#  '2161-0029': 0.52,
#  '2042-4876': nan,
#  '2701-0198': 0.67,
#  '2187-5219': 0.58,
#  '1568-5519': 1.17,
#  '2633-366X': 0.76,
#  '2522-0136': 2.7,
#  '2578-0727': 0.57,
#  '1872-8294': 2.56,
#  '2119-0275': 0.49,
#  '1931-4493': 0.35,
#  '1614-6840': 3.36,
#  '1527-2648': 1.07,
#  '2524-793X': 2.07,
#  '1616-3028': 2.59,
#  '2542-5048': 2.71,
#  '1879-8136': nan,
#  '2197-8441': nan,
#  '2055-0359': 1.1,
#  '1521-4095': 4.1,
#  '2196-7350': 0.99,
#  '0976-397X': nan,
#  '1662-8985': nan,
#  '2365-709X': 1.43,
#  '2519-4445': 1.06,
#  '2213-7467': 1.05,
#  '2169-0375': 1.26,
#  '2195-1071': 1.82,
#  '2192-8584': 0.91,
#  '2251-7308': 1.15,
#  '2577-5421': 4.29,
#  '1568-5527': 1.28,
#  '2511-9044': 1.24,
#  '1568-5535': 1.11,
#  '1936-7317': nan,
#  '2363-9466': 0.0,
#  '2198-0926': 2.14,
#  '1869-8441': nan,
#  '2508-7908': 0.46,
#  '1558-0334': nan,
#  '1314-7609': nan,
#  '2667-9930': 0.65,
#  '2366-7486': 1.01,
#  '1615-4169': 1.04,
#  '2513-0390': 0.88,
#  '2366-3987': 0.72,
#  '2576-2516': 0.09,
#  '2192-2659': 1.45,
#  '2310-5380': 0.55,
#  '1046-5715': 0.74,
#  '1687-627X': 1.03,
#  '1793-7175': nan,
#  '2524-6992': 1.09,
#  '2314-7539': 1.12,
#  '2287-5271': 0.51,
#  '2210-5735': 0.03,
#  '1533-4031': 2.28,
#  '2192-7065': nan,
#  '1878-0415': 0.42,
#  '2307-8316': 0.38,
#  '1743-6761': 0.81,
#  '1661-4909': 1.1,
#  '2666-7924': 3.32,
#  '1090-2074': 1.0,
#  '2075-1354': 0.58,
#  '1475-6064': 1.13,
#  '2326-3768': 0.84,
#  '1613-1851': nan,
#  '1687-7977': 0.55,
#  '1861-9533': 1.6,
#  '2056-3876': 0.5,
#  '1616-8542': nan,
#  '2468-0125': nan,
#  '1687-8035': 0.94,
#  '1662-2774': nan,
#  '2212-4934': 0.89,
#  '1879-811X': nan,
#  '1756-2201': 0.77,
#  '1875-810X': 0.14,
#  '1855-931X': 0.14,
#  '1864-8266': 1.18,
#  '2162-5557': nan,
#  '2162-5530': nan,
#  '1662-2839': nan,
#  '2080-2218': nan,
#  '1751-7605': 0.75,
#  '2468-9270': 1.12,
#  '1548-5609': 1.22,
#  '1687-8094': 0.72,
#  '2165-3984': 0.67,
#  '2524-1761': 1.53,
#  '2162-9471': 0.91,
#  '2451-2680': 0.65,
#  '1873-3727': 3.06,
#  '2517-5599': 2.2,
#  '2466-0523': 0.61,
#  '1572-9044': 1.07,
#  '2191-6594': nan,
#  '2287-531X': 0.84,
#  '1687-8124': 0.51,
#  '1862-5355': 1.49,
#  '2090-3367': 0.64,
#  '2192-6212': nan,
#  '1552-3055': 1.3,
#  '1687-1847': 1.7,
#  '2042-8324': 0.4,
#  '0974-021X': 0.85,
#  '1935-2719': nan,
#  '1844-7600': 0.42,
#  '1804-3119': 0.29,
#  '1873-5339': 1.85,
#  '1998-1066': nan,
#  '2476-4779': 0.17,
#  '1934-4694': nan,
#  '2214-8019': 0.95,
#  '1687-711X': 1.05,
#  '2208-598X': 2.0,
#  '1615-7168': 0.84,
#  '1680-7359': 0.6,
#  '2079-0570': 0.14,
#  '1573-1677': 1.9,
#  '1687-9112': 1.16,
#  '1687-7365': 0.57,
#  '1592-1573': 0.38,
#  '1687-5907': 2.29,
#  '1557-8445': nan,
#  '2193-1577': nan,
#  '2666-9129': 2.27,
#  '2233-9345': nan,
#  '2512-2193': nan,
#  '1557-8917': nan,
#  '2213-6800': nan,
#  '2212-9596': 0.46,
#  '2194-5365': 0.29,
#  '2628-491X': 0.28,
#  '1879-6974': 2.51,
#  '2195-3597': 1.49,
#  '2162-5875': 0.0,
#  '2234-179X': 0.66,
#  '1687-8442': 0.91,
#  '2374-0698': 2.2,
#  '1687-9139': 0.55,
#  '1090-2082': 1.91,
#  '1930-5338': 0.81,
#  '1857-8438': 0.34,
#  '1687-8140': 0.81,
#  '1179-7258': 1.01,
#  '1898-4002': 0.72,
#  '1875-8053': 0.08,
#  '1837-4905': 0.61,
#  '2044-1290': 0.67,
#  '1687-9317': 1.04,
#  '2515-2467': 7.58,
#  '2533-4123': 0.39,
#  '1532-1843': nan,
#  '2212-2044': nan,
#  '2215-0927': nan,
#  '1687-5699': 0.32,
#  '2287-2388': 0.81,
#  '2043-6262': 0.59,
#  '1998-1090': nan,
#  '2213-6959': nan,
#  '1536-0911': 1.02,
#  '2366-7540': 0.46,
#  '1878-9498': 0.41,
#  '2191-950X': 2.24,
#  '1550-5014': 1.18,
#  '2156-5376': 2.69,
#  '1947-573X': 0.45,
#  '1687-9155': 1.03,
#  '2538-225X': 0.83,
#  '2452-1760': 0.18,
#  '1687-6407': nan,
#  '1687-5648': 0.0,
#  '2212-408X': 0.19,
#  '2090-3472': 0.84,
#  '1662-2847': 2.04,
#  '1879-808X': 0.17,
#  '2163-6079': 0.96,
#  '1878-1926': 1.03,
#  '2633-4690': 1.0,
#  '1557-8925': nan,
#  '1687-7993': nan,
#  '1460-6976': 9.59,
#  '2374-6149': 2.09,
#  '1651-1948': nan,
#  '2529-8062': 0.0,
#  '1436-5030': nan,
#  '1098-2329': 0.91,
#  '2046-4118': nan,
#  '2090-1828': nan,
#  '2211-3509': nan,
#  '1855-6531': 1.29,
#  '1876-1631': 1.3,
#  '1472-1481': nan,
#  '1662-2855': nan,
#  '2314-7784': 1.36,
#  '1869-6090': 0.56,
#  '2051-2325': 0.0,
#  '1684-9973': 0.31,
#  '1734-4948': 0.37,
#  '2578-7268': 0.03,
#  '2543-6031': 0.47,
#  '2049-8535': nan,
#  '1992-0636': 0.94,
#  '2299-8624': 0.31,
#  '2415-6698': 0.45,
#  '2522-8722': 0.14,
#  '1538-8654': 1.08,
#  '2331-4125': 0.69,
#  '2212-781X': 0.56,
#  '1617-5034': nan,
#  '1879-1948': 1.23,
#  '2197-9375': nan,
#  '2364-3587': 0.71,
#  '2048-4011': 1.14,
#  '2518-2994': 0.59,
#  '1095-0753': 0.9,
#  '1865-8652': 1.34,
#  '2662-4060': 0.69,
#  '1687-5923': 1.94,
#  '1687-6377': 1.06,
#  '1687-8647': 0.62,
#  '1557-8399': nan,
#  '2675-9462': 0.61,
#  '2162-1934': 1.74,
#  '2190-5215': nan,
#  '2587-2648': 0.88,
#  '2212-6538': nan,
#  '2159-7774': 0.34,
#  '1827-7888': nan,
#  '1420-8903': 1.24,
#  '1573-3025': 0.62,
#  '2059-6464': 0.75,
#  '2510-3768': 0.42,
#  '1521-7388': 1.03,
#  '2071-1409': 0.91,
#  '2226-4310': 1.33,
#  '2523-3955': 0.55,
#  '2375-6322': 0.53,
#  '2421-7115': 0.06,
#  '1432-5241': 1.34,
#  '1527-330X': 1.51,
#  '1724-2118': 0.31,
#  '2194-4024': 0.23,
#  '1827-787X': 0.37,
#  '1552-3020': 1.55,
#  '2399-3588': 0.91,
#  '2550-1755': 1.08,
#  '1750-0184': 0.95,
#  '1753-5921': 0.54,
#  '0974-4061': 0.95,
#  '1868-6869': 1.59,
#  '1527-1978': 0.62,
#  '1468-2621': 3.0,
#  '1572-9842': 0.94,
#  '1937-2108': 0.33,
#  '2156-7263': 1.06,
#  '1467-8268': 1.17,
#  '1872-5465': 0.87,
#  '2163-9108': 0.94,
#  '2306-5133': 0.79,
#  '1729-0503': 0.52,
#  '1753-2531': 0.37,
#  '2211-145X': nan,
#  '1996-2096': 0.09,
#  '1472-5851': 0.81,
#  '1727-9445': 0.56,
#  '1727-9364': 0.82,
#  '1750-4562': 0.22,
#  '2226-7220': 1.23,
#  '1365-2028': 0.52,
#  '2040-0713': 0.83,
#  '2211-4203': 0.74,
#  '1684-5374': 0.31,
#  '2153-3660': 0.74,
#  '2223-814X': 0.37,
#  '2505-0419': 0.26,
#  '1755-1609': 0.46,
#  '2225-2010': 0.36,
#  '1708-7384': 0.1,
#  '1814-2338': 0.51,
#  '1992-2647': nan,
#  '0974-5998': 0.33,
#  '2071-2936': 0.94,
#  '1727-9380': 0.57,
#  '2469-7656': 0.57,
#  '2042-1346': 0.74,
#  '2409-5605': 0.57,
#  '2617-0205': 0.28,
#  '2505-0044': nan,
#  '1961-9987': 0.38,
#  '2410-8200': 0.62,
#  '2374-3689': 0.88,
#  '2516-5305': 0.18,
#  '1939-2214': 1.39,
#  '2154-0128': 0.9,
#  '1469-2872': 0.95,
#  '1555-2462': 1.35,
#  '2410-1516': 0.47,
#  '1569-2108': 0.26,
#  '1752-864X': 0.56,
#  '2034-8436': 0.25,
#  '2190-7668': 1.01,
#  '1776-2766': nan,
#  '2108-6796': 0.9,
#  '1751-6455': 0.76,
#  '2156-4914': 0.0,
#  '1468-2834': 2.62,
#  '2340-9592': 0.4,
#  '1936-606X': 0.93,
#  '1872-9649': 2.67,
#  '1469-1779': 1.39,
#  '2158-978X': 0.64,
#  '2452-0071': 0.01,
#  '1873-6335': 2.24,
#  '1098-2337': 1.49,
#  '1945-4589': 0.94,
#  '1474-9726': 1.58,
#  '1745-5103': nan,
#  '1473-0790': 0.97,
#  '2475-0360': 0.71,
#  '2663-8851': 0.35,
#  '2152-5250': 1.49,
#  '1364-6915': 1.57,
#  '1720-8319': 1.31,
#  '1744-4128': 0.92,
#  '1809-4414': 0.11,
#  '2174-3347': 0.22,
#  '2228-4893': 0.53,
#  '1663-7909': 0.2,
#  '2321-0281': 1.29,
#  '2527-9238': 0.81,
#  '2078-0400': 0.72,
#  '1825-1277': 0.0,
#  '2458-9446': 0.35,
#  '2624-7402': 1.11,
#  '1668-298X': 0.08,
#  '1520-6297': 1.27,
#  '1331-7776': 0.43,
#  '1839-5627': nan,
#  '1805-9295': 0.89,
#  '1574-0862': 1.73,
#  '2449-5999': 0.34,
#  '2041-6326': 0.96,
#  '2249-7218': 0.75,
#  '2395-146X': 0.18,
#  '0976-0547': 0.28,
#  '1873-2267': 1.97,
#  '1873-2283': 2.02,
#  '2471-9625': 0.82,
#  '2193-7532': 1.4,
#  '1795-1895': 0.55,
#  '1461-9563': 0.94,
#  '2414-584X': 0.62,
#  '2372-2614': 0.66,
#  '1338-4376': 0.52,
#  '2077-0472': 1.16,
#  '2048-7010': 1.7,
#  '1800-6492': 0.48,
#  '1572-8366': 1.38,
#  '2452-316X': 0.3,
#  '2477-8516': 0.62,
#  '2035-4606': nan,
#  '2521-9766': 0.32,
#  '2168-3573': 0.94,
#  '1572-9680': 0.97,
#  '1588-2713': 0.26,
#  '2357-3732': 0.29,
#  '2215-3608': 0.39,
#  '2073-4395': 1.21,
#  '1435-0645': 0.89,
#  '1773-0155': 2.43,
#  '2639-6696': 0.65,
#  '2340-7743': 0.84,
#  '2179-9784': 0.08,
#  '1813-5145': 0.63,
#  '2407-8646': 1.12,
#  '1532-6497': 0.53,
#  '1873-9326': 1.15,
#  '1875-8339': 0.6,
#  '1554-2505': nan,
#  '0718-7181': 0.17,
#  '2035-8466': 0.46,
#  '1803-7860': 0.25,
#  '2228-3897': 1.26,
#  '2146-2925': nan,
#  '2148-015X': 0.1,
#  '0779-7842': 0.04,
#  '2536-5738': 0.0,
#  '2079-2883': 0.0,
#  '2451-0696': nan,
#  '1438-938X': 0.13,
#  '1438-9916': 0.15,
#  '1438-9428': nan,
#  '1611-7697': nan,
#  '1438-9940': 0.03,
#  '1438-9436': nan,
#  '1438-8820': 0.23,
#  '2412-5679': 0.23,
#  '2570-8775': 0.29,
#  '2375-4036': 0.39,
#  '2442-3084': 0.93,
#  '2338-557X': 1.2,
#  '1473-348X': 0.5,
#  '1988-2955': 1.17,
#  '2232-1969': 1.17,
#  '2289-3687': 0.19,
#  '1923-1857': 0.38,
#  '1752-0754': 0.75,
#  '1873-6823': 0.76,
#  '1464-3502': 1.06,
#  '2169-4796': 4.96,
#  '1544-4538': 0.64,
#  '1530-0277': 1.12,
#  '1807-0299': 0.08,
#  '1553-3956': 0.27,
#  '2083-2834': 0.06,
#  '1575-8435': nan,
#  '2093-0860': 0.8,
#  '1420-8911': 0.96,
#  '1573-8302': 0.68,
#  '2589-5486': 1.01,
#  '2214-2584': 1.97,
#  '2423-3447': 0.41,
#  '1472-2739': 0.94,
#  '1572-9079': 0.87,
#  '2157-6203': 0.21,
#  '1432-0541': 1.22,
#  '1365-2036': 2.09,
#  '1746-6342': nan,
#  '2766-9645': 0.52,
#  '2689-5307': 0.36,
#  '0973-5046': 0.35,
#  '2195-6405': nan,
#  '2197-0378': 0.9,
#  '1578-1267': 0.61,
#  '1440-1592': 2.45,
#  '1539-6304': 0.85,
#  '2152-6567': 1.28,
#  '1710-1492': 0.99,
#  '2092-7363': 1.03,
#  '1398-9995': 2.7,
#  '1600-549X': nan,
#  '2339-9694': 0.49,
#  '0718-2201': 0.28,
#  '1664-221X': 0.92,
#  '2535-0889': 0.45,
#  '2279-7335': 0.36,
#  '1875-0680': 0.94,
#  '1174-1740': 1.54,
#  '1989-9971': 0.43,
#  '2398-9084': nan,
#  '1557-9085': 0.05,
#  '2163-3150': 0.75,
#  '1868-8551': 0.96,
#  '2196-6761': 1.34,
#  '1546-4156': 0.86,
#  '1550-3240': nan,
#  '1936-6760': nan,
#  '1552-5279': 3.49,
#  ...}

# %%
cwts_year
# Out:
# Year                                        Source title Electronic ISSN  \
# 0      2000 IEEE Wireless Communications and Networki...               -
# 1                                     21st Century Music               -
# 2                                           2D Materials       2053-1583
# 3                                              3 Biotech       2190-5738
# 4                 3D Printing and Additive Manufacturing       2329-7670
# ...                                                  ...             ...
# 33970               npj Systems Biology and Applications       2056-7189
# 33971                                       npj Vaccines       2059-0105
# 33972      primary care companion for CNS disorders, The       2155-7780
# 33973                                        rEFLections       2651-1479
# 33974                                          sub\urban       2197-2567
#
# Year   1999  2000  2001  2002  2003  2004  2005  2006  ...  2013  2014  2015  \
# 0       NaN   NaN  0.64  1.25  1.27  0.90  0.64   NaN  ...   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN  0.00  0.00  0.00  ...   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  1.28
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.62  0.00  0.14
# 4       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  1.63
# ...     ...   ...   ...   ...   ...   ...   ...   ...  ...   ...   ...   ...
# 33970   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 33971   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 33972   NaN  0.35  0.08  0.15  0.15  0.41  0.57  0.66  ...  0.70  0.58  0.58
# 33973   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 33974   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN  0.01  0.59
#
# Year   2016  2017  2018  2019  2020  2021  2022
# 0       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2      1.04  1.22  1.33  1.46  1.42  1.33  1.13
# 3      1.17  1.11  1.17  0.95  0.96  0.86  0.81
# 4      1.39  1.33  1.42  1.35  1.39  1.20  1.10
# ...     ...   ...   ...   ...   ...   ...   ...
# 33970  1.20  1.12  0.99  1.22  1.12  1.08  0.97
# 33971   NaN  0.40  1.30  1.34  1.62  1.99  1.63
# 33972  0.55  0.59  0.58  0.65  0.59  0.48  0.25
# 33973   NaN   NaN   NaN   NaN   NaN  0.48  0.73
# 33974  0.52  0.32  0.58  0.09  0.34  0.41  0.47
#
# [33975 rows x 26 columns]
